# %%
from IPython.display import display, Math, Latex
import pandas as pd
import numpy as np
#import numpy_financial as npf
import yfinance as yf
import matplotlib.pyplot as plt
import itertools
import copy
from datetime import datetime

# %%
MinStocks = 10
MaxStocks = 22
MaxWeight = 0.2
MinWeight = 0.05
Start_date = "2023-01-01"
End_date = "2023-06-30"
TradingFee = 4.95
InvestmentAmount = 750000

# %%
tickers = pd.read_csv("example_tickers2.csv")
tickers
# Out:
#       CNR.TO
# 0      CP.TO
# 1     TRI.TO
# 2     WCN.TO
# 3     WSP.TO
# 4      AC.TO
# 5     TIH.TO
# 6    TFII.TO
# 7     SNC.TO
# 8     CAE.TO
# 9     BHC.TO
# 10   WEED.TO
# 11    TMD.TO
# 12    ACB.TO
# 13    CPH.TO
# 14    EXE.TO
# 15    OGI.TO
# 16    SIA.TO
# 17    GUD.TO
# 18   WELL.TO
# 19    CAE.TO
# 20    KXS.TO
# 21   SHOP.TO
# 22    DSG.TO
# 23   ENGH.TO
# 24    CSU.TO
# 25  GIB-A.TO
# 26   OTEX.TO
# 27    CTS.TO
# 28     BB.TO
# 29    ENB.TO
# 30    TRP.TO
# 31    ERF.TO
# 32     SU.TO
# 33    IMO.TO
# 34    CVE.TO
# 35    PPL.TO
# 36    POU.TO
# 37    CNQ.TO
# 38    MEG.TO
# 39     RY.TO
# 40    BNS.TO
# 41     NA.TO
# 42     TD.TO
# 43    BMO.TO
# 44     CM.TO
# 45    MFC.TO
# 46    IFC.TO
# 47    SLF.TO
# 48    FFH.TO
